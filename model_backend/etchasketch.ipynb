# %%
# !unzip -qq zip.zip -d '/content'
# !mv -v ./zip/* ./
# Out:
# replace /content/zip/data_info.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# renamed './zip/Checkpoints' -> './Checkpoints'
# renamed './zip/Data' -> './Data'
# renamed './zip/data_info.txt' -> './data_info.txt'
# renamed './zip/Dataset' -> './Dataset'
# renamed './zip/DataUtils' -> './DataUtils'
# renamed './zip/LICENSE' -> './LICENSE'
# renamed './zip/log.txt' -> './log.txt'
# renamed './zip/main.py' -> './main.py'
# renamed './zip/Model' -> './Model'
# renamed './zip/README.md' -> './README.md'

# %%
# !python ./DataUtils/prepare_data.py -c all -d 1 -show --max_samples_category 5000
# Out:
# ['aircraft_carrier', 'airplane', 'alarm_clock', 'ambulance', 'angel', 'animal_migration', 'ant', 'anvil', 'apple', 'arm', 'asparagus', 'axe', 'backpack', 'banana', 'bandage', 'barn', 'baseball', 'baseball_bat', 'basket', 'basketball', 'bat', 'bathtub', 'beach', 'bear', 'beard', 'bed', 'bee', 'belt', 'bench', 'bicycle', 'binoculars', 'bird', 'birthday_cake', 'blackberry', 'blueberry', 'book', 'boomerang', 'bottlecap', 'bowtie', 'bracelet', 'brain', 'bread', 'bridge', 'broccoli', 'broom', 'bucket', 'bulldozer', 'bus', 'bush', 'butterfly', 'cactus', 'cake', 'calculator', 'calendar', 'camel', 'camera', 'camouflage', 'campfire', 'candle', 'cannon', 'canoe', 'car', 'carrot', 'castle', 'cat', 'ceiling_fan', 'cello', 'cell_phone', 'chair', 'chandelier', 'church', 'circle', 'clarinet', 'clock', 'cloud', 'coffee_cup', 'compass', 'computer', 'cookie', 'cooler', 'couch', 'cow', 'crab', 'crayon', 'crocodile', 'crown', 'cruise_ship', 'cup', 'diamond', 'dishwasher', 'diving_board', 'dog', 'dolphin'
# ...

# %%
# !python main.py --epochs 10 --batch_size 128 --learning_rate 0.01 --momentum 0.9 --ngpu 1 --model resnet34 # --image_size 56
# Out:
# **************************************************
# Loading the data...
# **************************************************
# Loading train dataset...
# **************************************************
# Classes number of train dataset: 345
# **************************************************
# tcmalloc: large alloc 8655364096 bytes == 0x51dc000 @  0x7f6f5b8d71e7 0x7f6e9f6320ce 0x7f6e9f688cf5 0x7f6e9f635948 0x5947d6 0x548cc1 0x5127f1 0x549576 0x593fce 0x548ae9 0x5127f1 0x4bc98a 0x533274 0x4d3969 0x512147 0x593dd7 0x5118f8 0x549576 0x4bca8a 0x532b86 0x594a96 0x548cc1 0x5127f1 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f6f5b4d4c87
# tcmalloc: large alloc 4327686144 bytes == 0x209a76000 @  0x7f6f5b8d71e7 0x7f6e9f6320ce 0x7f6e9f68c726 0x7f6e9f721841 0x59b076 0x515655 0x593dd7 0x5118f8 0x549576 0x4bca8a 0x532b86 0x594a96 0x548cc1 0x5127f1 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f6f5b4d4c87 0x5b621a
# Dataset train loading done.
# ...
